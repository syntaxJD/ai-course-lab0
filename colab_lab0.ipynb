# %%
 # Lab 0: Colab Practice - [Jedediah Klenam Dogbey]

# %%
# Lab 0: Colab Practice - [Jedediah Klenam Dogbey]
Student_ID: [26782028]

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Running on Colab: {'google.colab' in sys.modules}")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Running on Colab: True

# %%
# Cell 3: Check GPU (Improved)
import subprocess

try:
    gpu_info = subprocess.run(['nvidia-smi'],
                              capture_output=True,
                              text=True,
                              timeout=10)
    if gpu_info.returncode == 0:
        print("✅ GPU Available:")
        print(gpu_info.stdout)
    else:
        print("⚠️ No GPU detected.")
except Exception as e:
    print("⚠️ GPU check failed (this is normal on CPU runtime)")
    print("Go to: Runtime → Change runtime type → Hardware accelerator → T4 GPU")
# Out:
# ⚠️ GPU check failed (this is normal on CPU runtime)
# Go to: Runtime → Change runtime type → Hardware accelerator → T4 GPU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wordcloud -q

from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Artificial Intelligence Machine Learning Deep Learning Neural Networks Python Pandas NumPy Matplotlib Seaborn Ashesi University Ghana"
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('AI Course Word Cloud')
plt.show()
